# %%
import time

from matplotlib import pyplot as plt

from src import em_algorithm, random_graph
from src.utils import sort_parameters

# %%
def benchmark(n, Q, implementations, runs=10, iterations=10):
    X, _, alpha, pi = random_graph(n, Q)
    alpha, pi = sort_parameters(alpha, pi)
    times = []

    for implementation in implementations:
        times.append([])
        for i in range(runs):
            print("Run", i + 1, "with", implementation, "implementation", end="\r")
            start_time = time.time()
            em_algorithm(
                X,
                Q,
                n_init=1,
                iterations=iterations,
                implementation=implementation,
                verbose=False,
            )
            times[-1].append(time.time() - start_time)
    return times

# %%
Q = 3
n = 100
times = benchmark(n, Q, implementations=["pytorch", "pytorch_log", "numpy"])

plt.boxplot(times, labels=["pytorch", "pytorch_log", "numpy"])
plt.yscale("log")
plt.xlabel("Implementation")
plt.ylabel("Time (seconds)")
plt.show()
# Out:
# Run 10 with numpy implementationtation
